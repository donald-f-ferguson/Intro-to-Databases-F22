# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases<br>
# Spring 2022, Sections 002, V02
# </span>
# </center></b>
# </span><br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Some Examples of Non-Programming: Game of Thrones<br>
# </span>
# </center></i>

# %% [markdown]
# # Introduction
#
# - There are a lot of interesting data sets and data science projects related to [Game of Thrones](https://www.imdb.com/title/tt0944947/), e.g.
#     - https://jeffreylancaster.github.io/game-of-thrones/
#     - https://data.world/datasets/game-of-thrones
#     - https://www.kaggle.com/mylesoneill/game-of-thrones
#
#
# - Doing interesting things with the data requires:
#     1. Extract: Get the data from various locations.
#     2. Transform: Change format, correct errors, ... ...
#     3. Load: Load into a database management system(s) for analysis.
#
#
# | ![image.png](attachment:image.png) |
# | :---: |
# | __Simple ETL Concept__ |

# %% [markdown]
# Notes:
#
# - Transform I:
#     - If "code" is necessary, the TAs or I will do the coding for students
#     - There will be cases where students use data tools to perform Transform I
#
#
# - Non-programming track homework/project will focus on:
#     - Load
#     - SQL (or other) transformation to an analyzable form
#     - Simple analysis

# %% [markdown]
# # An Example
#
# - After converting to CSVs, I got some relational tables that we not cool.

# %%
# %load_ext sql
# %sql mysql+pymysql://dbuser:dbuserdbuser@localhost/GOTProcessed

# %%
# %sql select * from GOT.scenes limit 10
# Out:
#  * mysql+pymysql://dbuser:***@localhost/GOTProcessed
# 10 rows affected.
# [(0, '0:00:40', '0:01:45', 'The Wall', 'Castle Black', "[{'name': 'Gared', 'seaonNumber': 1, 'episodeNumber': 1}, {'name': 'Waymar Royce', 'seaonNumber': 1, 'episodeNumber': 1}, {'name': 'Will', 'seaonNumber': 1, 'episodeNumber': 1}]", '1', '1', 'nan', 'nan', 'nan', 'nan'),
#  (1, '0:01:45', '0:03:24', 'North of the Wall', 'The Haunted Forest', "[{'name': 'Gared', 'seaonNumber': 1, 'episodeNumber': 1}, {'name': 'Waymar Royce', 'seaonNumber': 1, 'episodeNumber': 1}, {'name': 'Will', 'seaonNumber': 1, 'episodeNumber': 1}]", '1', '1', 'nan', 'nan', 'nan', 'nan'),
#  (2, '0:03:24', '0:03:31', 'North of the Wall', 'The Haunted Forest', "[{'name': 'Will', 'seaonNumber': 1, 'episodeNumber': 1}, {'name': 'Wight Wildling Girl', 'alive': False, 'seaonNumber': 1, 'episodeNumber': 1}]", '1', '1', 'nan', 'nan', 'nan', 'nan'),
#  (3, '0:03:31', '0:03:38', 'North of the Wall', 'The Haunted Forest', "[{'name': 'Will', 'seaonNumber': 1, 'episodeNumber': 1}]", '1', '1', 'nan', 'nan', 'nan', 'nan'),
#  (4, '0:03:38', '0:03:44', 'North of the Wall', 'The Haunted Forest', '[]', '1', '1', 'nan', 'nan', 'nan', 'nan'),
#  (5, '0:03:44', '0:05:36', 'North of the Wall', 'The Haunted Forest', "[{'name': 'Gared', 'seaonNumber': 1, 'episodeNumber': 1}, {'name': 'Waymar Royce', 'seaonNumber': 1, 'episodeNumber': 1}, {'name': 'Will', 'seaonNumber': 1, 'episodeNumber': 1}]", '1', '1', 'nan', 'nan', 'nan', 'nan'),
#  (6, '0:05:36', '0:05:41', 'North of the Wall', 'The Haunted Forest', "[{'name': 'Will', 'seaonNumber': 1, 'episodeNumber': 1}]", '1', '1', 'nan', 'nan', 'nan', 'nan'),
#  (7, '0:05:41', '0:05:48', 'North of the Wall', 'The Haunted Forest', "[{'name': 'Gared', 'seaonNumber': 1, 'episodeNumber': 1}, {'name': 'Waymar Royce', 'seaonNumber': 1, 'episodeNumber': 1}]", '1', '1', 'nan', 'nan', 'nan', 'nan'),
#  (8, '0:05:48', '0:05:58', 'North of the Wall', 'The Haunted Forest', "[{'name': 'Will', 'seaonNumber': 1, 'episodeNumber': 1}]", '1', '1', 'nan', 'nan', 'nan', 'nan'),
#  (9, '0:05:58', '0:06:21', 'North of the Wall', 'The Haunted Forest', "[{'name': 'Gared', 'seaonNumber': 1, 'episodeNumber': 1}, {'name': 'Waymar Royce', 'alive': False, 'mannerOfDeath': 'Back stab', 'killedBy': ['White Walker'], 'seaonNumber': 1, 'episodeNumber': 1}, {'name': 'White Walker', 'seaonNumber': 1, 'episodeNumber': 1}]", '1', '1', 'nan', 'nan', 'nan', 'nan')]

# %%
# %sql select * from GOT.locations limit 10
# Out:
#  * mysql+pymysql://dbuser:***@localhost/GOTProcessed
# 10 rows affected.
# [(0, 'North of the Wall', '[\'The Lands of Always Winter\', \'Cave Outside Wildling Camp\', \'Wildling Camp\', \'Frostfang Mountains\', \'The Three-Eyed Raven\', \'Outside the  ... (88 characters truncated) ... March South\', \'Hardhome\', "Craster\'s Keep", \'The Haunted Forest\', \'South to the Wall\', \'Destroyed Cabin\', \'Near Nightfort\', \'The Wall\']'),
#  (1, 'The Wall', '[\'Nightfort\', \'Eastwatch\', \'Top of the Wall\', \'Castle Black\', \'Outside Castle Black\', "Mole\'s Town", \'The Gift\']'),
#  (2, 'The North', '[\'The Gift\', \'Last Hearth\', \'Bear Island\', \'North to the Wall\', \'Deepwood Motte\', "Stannis Baratheon\'s Camp", \'The Wolfswood\', \'Outside Winterfell\', \'Winterfell\', \'Winter Town\', \'The Dreadfort\', "The Kingsroad South to King\'s Landing", \'Moat Cailin\', \'The Neck\']'),
#  (3, 'The Shivering Sea', "['']"),
#  (4, 'The Vale', "['Runestone', 'The Eyrie', 'To The Eyrie', 'Eastern Road', 'To the Westerlands', 'Outside the Inn', 'Inn', 'To The Vale', 'Coast of the Vale']"),
#  (5, 'The Iron Islands', "['', 'Pyke', 'Lordsport']"),
#  (6, 'The Sunset Sea', "['']"),
#  (7, 'The Westerlands', '[\'Casterly Rock\', \'Outside Casterly Rock\', \'Oxcross\', \'Lannister Camp\', \'Camp of the North\', "To King\'s Landing"]'),
#  (8, 'The Riverlands', '[\'The Twins\', \'Away from the Twins\', \'To The Twins\', \'To The Eyrie\', \'Lannister Camp\', \'Battlefield\', \'Camp of the North\', \'Village\', ... (102 characters truncated) ... rrun\', \'Red Fork\', \'To Riverrun\', \'North to the Red Fork\', \'To Harrenhal\', \'Harrenhal\', \'Outside Harrenhal\', "South to King\'s Landing"]'),
#  (9, 'The Narrow Sea', "['']")]

# %% [markdown]
# - In this course,
#     - We will learn why this format for data is "icky."
#     - How and why to transform.
#
#
# - I wrote some SQL and produced a database ```GOTProcessed.```
#
#
# - Using the processed data, I can get information about scenes, locations, etc.

# %%
l_data = %sql SELECT location, subLocation, count(*) as count  FROM scenes \
	group by location, subLocation having count > 25 order by count desc;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/GOTProcessed
# 30 rows affected.

# %%
l_data
# Out:
# [('The Crownlands', "King's Landing", 1093),
#  ('The North', 'Winterfell', 734),
#  ('The Wall', 'Castle Black', 267),
#  ('Meereen', None, 168),
#  ('The Crownlands', 'Dragonstone', 142),
#  ('Braavos', None, 103),
#  ('North of the Wall', 'The Haunted Forest', 77),
#  ('The North', 'Outside Winterfell', 69),
#  ('North of the Wall', "Craster's Keep", 66),
#  ('North of the Wall', 'The Wall', 59),
#  ('The Riverlands', 'The Twins', 57),
#  ('The Crownlands', 'Blackwater Rush', 56),
#  ('The Crownlands', 'Blackwater Bay', 53),
#  ('The Riverlands', 'Harrenhal', 50),
#  ('The Riverlands', 'Riverrun', 47),
#  ('North of the Wall', 'The Three-Eyed Raven', 44),
#  ('Vaes Dothrak', None, 38),
#  ('North of the Wall', 'Hardhome', 38),
#  ('Qarth', None, 35),
#  ('The North', 'The Dreadfort', 34),
#  ('The North', "Stannis Baratheon's Camp", 33),
#  ('The Narrow Sea', None, 32),
#  ('The Wall', 'Eastwatch', 32),
#  ('The North', 'The Gift', 31),
#  ('Dorne', 'The Water Gardens', 30),
#  ('Yunkai', 'Outside Yunkai', 29),
#  ('The Crownlands', "Outside King's Landing", 29),
#  ('The Riverlands', 'To The Eyrie', 28),
#  ('The Vale', 'The Eyrie', 27),
#  ('The Iron Islands', 'Pyke', 27)]

# %% [markdown]
# # Simple Visualization
#
# - The table is OK, but people tend to like figures.
#
#
# - Let's build a heatmap. Specifically, I do not want a list of the form ```(location, sublocation),``` I want a matrix with intensity.

# %%
import pandas

# %%
l_df = l_data.DataFrame()
l_df = l_df[['location', 'subLocation', 'count']]

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
heatmap1_data = pandas.pivot_table(l_df, values='count', 
                     index=['location'], 
                     columns='subLocation')

# %%
plt.figure(figsize=(20, 10))
sb.heatmap(heatmap1_data, cmap="YlGnBu")

plt.show()

# %% [markdown]
# - Counting the number of scenes in ```(location, sublocation)``` is interesting.
#
#
# - Maybe I want to know the total screen time in ```(location, sublocation).```

# %%
# %%sql
#     df2 << SELECT
# 	location, sublocation,
#         cast(sum(timediff(sceneEnd, sceneStart)) as unsigned) as running_time
#         FROM GOTProcessed.scenes
#     group by location, sublocation
#     having (sublocation is not null)
#     order by running_time desc
#     limit 50
# Out:
#  * mysql+pymysql://dbuser:***@localhost/GOTProcessed
# 50 rows affected.
# Returning data to local variable df2

# %%
df2 = df2.DataFrame()
df2
# Out:
#              location               sublocation  running_time
# 0      The Crownlands            King's Landing         85947
# 1           The North                Winterfell         40990
# 2            The Wall              Castle Black         22493
# 3      The Crownlands               Dragonstone         16326
# 4      The Riverlands                 Harrenhal          5232
# 5   North of the Wall        The Haunted Forest          4807
# 6   North of the Wall            Craster's Keep          4469
# 7      The Riverlands                  Riverrun          4389
# 8            The Vale                 The Eyrie          4310
# 9           The North             The Dreadfort          3785
# 10     The Riverlands                 The Twins          3684
# 11     The Crownlands    Outside King's Landing          3614
# 12          The North        Outside Winterfell          3545
# 13     The Riverlands              To The Eyrie          3371
# 14     The Stormlands               Storm's End          3290
# 15    The Westerlands         Camp of the North          2995
# 16  North of the Wall       Frostfang Mountains          2875
# 17   The Iron Islands                      Pyke          2836
# 18          The North  Stannis Baratheon's Camp          2811
# 19          The Reach                   Oldtown          2706
# 20     The Riverlands            Crossroads Inn          2456
# 21  North of the Wall                  Hardhome          2265
# 22             Yunkai            Outside Yunkai          2104
# 23     The Riverlands               Hollow Hill          2067
# 24     The Crownlands            Blackwater Bay          2019
# 25              Dorne         The Water Gardens          2017
# 26     The Riverlands         Camp of the North          2012
# 27  North of the Wall                  The Wall          1960
# 28     The Riverlands             The Kingsroad          1896
# 29          The North                  The Gift          1855
# 30  North of the Wall      The Three-Eyed Raven          1697
# 31     The Crownlands           Blackwater Rush          1671
# 32     The Riverlands            Lannister Camp          1626
# 33          The North         North to the Wall          1516
# 34          The North               Moat Cailin          1506
# 35          The North             The Wolfswood          1436
# 36  North of the Wall     Fist of the First Men          1370
# 37           The Vale              To The Eyrie          1247
# 38          The Reach                 Horn Hill          1201
# 39     The Riverlands    East to King's Landing          1169
# 40     The Riverlands              To Harrenhal          1074
# 41     The Riverlands                   Village          1052
# 42           The Wall               Mole's Town           962
# 43          The Reach                Highgarden           919
# 44    The Westerlands            Lannister Camp           874
# 45   The Dothraki Sea             Dothraki Camp           853
# 46          The North               Winter Town           778
# 47     The Riverlands   South to King's Landing           761
# 48            Meereen           Outside Meereen           747
# 49              Dorne              Tower of Joy           697

# %%
heatmap1_data = pandas.pivot_table(df2, values='running_time', 
                     index=['location'], 
                     columns='sublocation')

# %%
plt.figure(figsize=(20, 10))
sb.heatmap(heatmap1_data, cmap="YlGnBu")

plt.show()
