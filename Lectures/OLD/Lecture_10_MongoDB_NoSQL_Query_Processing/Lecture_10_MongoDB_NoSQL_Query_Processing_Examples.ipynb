# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
#
# }
#
# </style>
#
# <b><center>
#     <span style="font-size: 24pt; line-height: 1.2;">COMS W4111: Introduction to Databases</span><br>
#     <span style="font-size: 24pt; line-height: 1.2;">Section 002, Spring, 2020</span><br>
# </center></b>
# <br><br>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2;">Lecture 8: MongoDB, NoSQL, Query Processing, Examples</span>
# </center></i>

# %% [markdown]
# # Lecture Material
#
# - The lecture material is on the site and repository.
#
#
# - This Jupyter notebook is for running example code and sample applications.

# %% [markdown]
# # Connect to MongoDB

# %%
# !pip install pymongo
# Out:
# ...
#      |████████████████████████████████| 419kB 3.5MB/s eta 0:00:01
# ...

# %%
from pymongo import MongoClient

# %%
mongo_conn = MongoClient(
                host="localhost",
                port=27017
            )

# %% [markdown]
# - Test the connection ...

# %%
# What databases do we have?
print("We have the following databases in this server:")
for d in mongo_conn.list_database_names():
    print("\t", d)
# Out:
# We have the following databases in this server:
# 	 CULPA
# 	 Forums
# 	 GOT
# 	 admin
# 	 classic_models
# 	 config
# 	 db
# 	 fantasy_basevall
# 	 local
# 	 new_forum

# %%
forum_db = mongo_conn.new_forum
forum_coll = forum_db.forum
forum_coll
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'new_forum'), 'forum')

# %%
the_post = forum_coll.find(
    {"post_id": "00014f99-a9cc-47ba-9370-a26936aa44f5"},
    {"post_id": 1, "children": 1})
the_post = list(the_post)
the_post = the_post[0]
the_post
# Out:
# {'_id': ObjectId('60689ecfb8f373edd26f1263'),
#  'post_id': '00014f99-a9cc-47ba-9370-a26936aa44f5',
#  'children': [{'comment_id': '4396adfd-6e0d-41aa-89c1-eabff020067b',
#    'parent_id': '00014f99-a9cc-47ba-9370-a26936aa44f5',
#    'response_date': '7/7/2020',
#    'email': 'spetrashovpr@ebay.co.uk',
#    'response_text': 'Duis aliquam convallis nunc. Proin at turpis a pede posuere nonummy. Integer non velit.\n\nDonec diam neque, vestibulum eget, vulputate ut, ultrices vel, augue. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis sapien sapien non mi. Integer ac neque.\n\nDuis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.',
#    'tags': ['HW2', 'OFFICE_HOURS']},
#   {'comment_id': '909ace3d-fc9e-41d3-a7a0-d3c85f4afc4c',
#    'parent_id': '00014f99-a9cc-47ba-9370-a26936aa44f5',
#    'response_date': '5/3/2020',
# ...

# %%
#
# verb where clause data
# select ... where ...
# delete ... where ....
# update set .... where ...


the_post = forum_coll.update_one(
    {"post_id": "00014f99-a9cc-47ba-9370-a26936aa44f5"},
    { "$push": { "children": {"professor_ferguson_is_jerk": 1}}})

# %%
the_post = forum_coll.find(
    {"post_id": "00014f99-a9cc-47ba-9370-a26936aa44f5"},
    {"post_id": 1, "children": 1})
the_post = list(the_post)
the_post = the_post[0]
the_post
# Out:
# {'_id': ObjectId('60689ecfb8f373edd26f1263'),
#  'post_id': '00014f99-a9cc-47ba-9370-a26936aa44f5',
#  'children': [{'comment_id': '4396adfd-6e0d-41aa-89c1-eabff020067b',
#    'parent_id': '00014f99-a9cc-47ba-9370-a26936aa44f5',
#    'response_date': '7/7/2020',
#    'email': 'spetrashovpr@ebay.co.uk',
#    'response_text': 'Duis aliquam convallis nunc. Proin at turpis a pede posuere nonummy. Integer non velit.\n\nDonec diam neque, vestibulum eget, vulputate ut, ultrices vel, augue. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis sapien sapien non mi. Integer ac neque.\n\nDuis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.',
#    'tags': ['HW2', 'OFFICE_HOURS']},
#   {'comment_id': '909ace3d-fc9e-41d3-a7a0-d3c85f4afc4c',
#    'parent_id': '00014f99-a9cc-47ba-9370-a26936aa44f5',
#    'response_date': '5/3/2020',
# ...

# %% [markdown]
# # Programmatic Access

# %% [markdown]
# - Get a list of just the seasons' base info of the Game of Thrones DB.

# %%
got_db = mongo_conn.GOT

# %%
print("The DB = ", got_db)
# Out:
# The DB =  Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'GOT')

# %%
# Get the collection; would be a table in SQL

# %%
got_seasons = got_db.seasons
print("The seasons collection = \n", got_seasons)
# Out:
# The seasons collection =
#  Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'GOT'), 'seasons')

# %%
#
import json
# Get information about just the series.
for s in got_seasons.find():
    print(s["season"], s["first_aired"], s["last_aired"], s["novels_notes"], s["url"])
# Out:
# 1 17-Apr-11 19-Jun-11 A Game of Thrones https://gameofthrones.fandom.com/wiki/Season_1
# 2 1-Apr-12 3-Jun-12 A Clash of Kings https://gameofthrones.fandom.com/wiki/Season_2
# 3 31-Mar-13 9-Jun-13 A Storm of Swords https://gameofthrones.fandom.com/wiki/Season_3
# 4 6-Apr-14 15-Jun-14 A Storm of Swords https://gameofthrones.fandom.com/wiki/Season_4
# 5 12-Apr-15 14-Jun-15 A Feast for Crows, A Dance with Dragons and original content https://gameofthrones.fandom.com/wiki/Season_5
# 6 24-Apr-16 26-Jun-16 Outline from The Winds of Winter and original content https://gameofthrones.fandom.com/wiki/Season_6
# 7 16-Jul-17 27-Aug-17 Outline from A Dream of Spring and original content https://gameofthrones.fandom.com/wiki/Season_7
# 8 14-Apr-19 19-May-19 Outline from A Dream of Spring and original content https://gameofthrones.fandom.com/wiki/Season_8

# %% [markdown]
# - The example above got all of the data, and just displayed some of the fields.
#
#
# - Is there a way to get the documents, but "exclude" fields that I do not want in the result?
#
#
# - Yes.

# %%
for s in got_seasons.find({}, {"episodes": 0, "_id": 0}):
    print(json.dumps(s, indent=2))
# Out:
# {
#   "season": "1",
#   "first_aired": "17-Apr-11",
#   "last_aired": "19-Jun-11",
#   "novels_notes": "A Game of Thrones",
#   "url": "https://gameofthrones.fandom.com/wiki/Season_1",
#   "thumbnail": "/assets/season1.png"
# }
# {
#   "season": "2",
#   "first_aired": "1-Apr-12",
#   "last_aired": "3-Jun-12",
#   "novels_notes": "A Clash of Kings",
#   "url": "https://gameofthrones.fandom.com/wiki/Season_2",
#   "thumbnail": "/assets/season2.png"
# }
# {
#   "season": "3",
#   "first_aired": "31-Mar-13",
#   "last_aired": "9-Jun-13",
#   "novels_notes": "A Storm of Swords",
#   "url": "https://gameofthrones.fandom.com/wiki/Season_3",
#   "thimbnail": "/assets/season3.png",
#   "thumbnail": "/assets/season3.png"
# }
# {
#   "season": "4",
#   "first_aired": "6-Apr-14",
#   "last_aired": "15-Jun-14",
#   "novels_notes": "A Storm of Swords",
#   "url": "https://gameofthrones.fandom.com/wiki/Season_4",
#   "thumbnail": "/assets/season4.png"
# }
# {
#   "season": "5",
# ...

# %% [markdown]
# - Examples:
#     - The first example got all the documents from the database, and then displayed just a subset of fields.
#     - The second example, got all the documents but without some of the sub-fields.
#
#
# - I have sort of seen something like a "project." Is there a way to do "select?"
#
#
# - Yes.

# %%
for s in got_seasons.find({"season": "3"}, {"episodes": 0, "_id": 0}):
    print(json.dumps(s, indent=2))
# Out:
# {
#   "season": "3",
#   "first_aired": "31-Mar-13",
#   "last_aired": "9-Jun-13",
#   "novels_notes": "A Storm of Swords",
#   "url": "https://gameofthrones.fandom.com/wiki/Season_3",
#   "thimbnail": "/assets/season3.png",
#   "thumbnail": "/assets/season3.png"
# }

# %% [markdown]
# - You can see the basic structure of the query is a "find."  The basic structure is
# ```
# find(
#         { .... } # A select statement.
#         { .... } # Projection.
# )
# ```
#
# - There are obviously a lot of other operations and variations.

# %% [markdown]
# # Interactive Query
#
# - Like RDB/SQL, there is programmatic access from various languages
#
#
# - And an interactive query approach, but it is much more programmatic.
#
#
# - __Note:__ Switch to PowerPoint, then Command Shell, then Compass

# %% [markdown]
# # Run PowerPoint Queries
#
# ## find()

# %%
# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb://localhost:27017/?readPreference=primary&appname=MongoDB%20Compass&ssl=false')
filter={
    'episodes.scenes.location': 'The Dothraki Sea'
}
project={
    'season': 1, 
    'episodes.episodeNum': 1, 
    'episodes.episodeLink': 1, 
    'episodes.episodeTitle': 1
}

result = client['GOT']['seasons'].find(
  filter=filter,
  projection=project
)

# %%
print(result)

# %%
for d in result:
    print(json.dumps(d, indent=2, default=str))
# Out:
# {
#   "_id": "60577e50c68b67110968b6d1",
#   "season": "1",
#   "episodes": [
#     {
#       "episodeNum": 1,
#       "episodeTitle": "Winter Is Coming",
#       "episodeLink": "/title/tt1480055/"
#     },
#     {
#       "episodeNum": 2,
#       "episodeTitle": "The Kingsroad",
#       "episodeLink": "/title/tt1668746/"
#     },
#     {
#       "episodeNum": 3,
#       "episodeTitle": "Lord Snow",
#       "episodeLink": "/title/tt1829962/"
#     },
#     {
#       "episodeNum": 4,
#       "episodeTitle": "Cripples, Bastards, and Broken Things",
#       "episodeLink": "/title/tt1829963/"
#     },
#     {
#       "episodeNum": 5,
#       "episodeTitle": "The Wolf and the Lion",
#       "episodeLink": "/title/tt1829964/"
#     },
#     {
#       "episodeNum": 6,
#       "episodeTitle": "A Golden Crown",
#       "episodeLink": "/title/tt1837862/"
#     },
#     {
#       "episodeNum": 7,
#       "episodeTitle": "You Win or You Die",
#       "episodeLink": "/title/tt1837863/"
#     },
# ...

# %% [markdown]
# # Impedance Mismatch
#
#
# - We are to look at ```classicmodels.```
#
#
# - Let's consider and order form or order printout. We have seen this data tends to be nested.
#
#
# - But, the relational model is "flat" tables. Let's get all of the data for an order.

# %%
# %load_ext sql
# %sql mysql+pymysql://dbuser:dbuserdbuser@localhost/classicmodelsnew
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: dbuser@classicmodelsnew'

# %%
# %%sql
#     select *
#         from orders join orderdetails using(orderNumber)
#     where customerNumber=363
# Out:
#  * mysql+pymysql://dbuser:***@localhost/classicmodelsnew
# 34 rows affected.
# [(10100, datetime.date(2003, 1, 6), datetime.date(2003, 1, 13), datetime.date(2003, 1, 10), 'Shipped', None, 363, 'S24_3969', 49, Decimal('35.29'), 1),
#  (10100, datetime.date(2003, 1, 6), datetime.date(2003, 1, 13), datetime.date(2003, 1, 10), 'Shipped', None, 363, 'S18_2248', 50, Decimal('55.09'), 2),
#  (10100, datetime.date(2003, 1, 6), datetime.date(2003, 1, 13), datetime.date(2003, 1, 10), 'Shipped', None, 363, 'S18_1749', 30, Decimal('136.00'), 3),
#  (10100, datetime.date(2003, 1, 6), datetime.date(2003, 1, 13), datetime.date(2003, 1, 10), 'Shipped', None, 363, 'S18_4409', 22, Decimal('75.46'), 4),
#  (10192, datetime.date(2003, 11, 20), datetime.date(2003, 11, 29), datetime.date(2003, 11, 25), 'Shipped', None, 363, 'S24_2887', 23, Decimal('112.74'), 1),
# ...

# %%
# %%sql
#     select count(distinct orderNumber)
#          from orders join orderdetails using(orderNumber)
#             where customerNumber=363
#             group by customerNumber;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/classicmodelsnew
# 1 rows affected.
# [(3,)]

# %% [markdown]
# - If I look up the orders for a customer, I expect a list of orders. What I get is a table with
#     - One entry for each ```orderDetails```
#     - And a lot of duplicate information.
#
#
# - I can correct this impedance mismatch if data models with some code.

# %%
import pymysql
import json

conn = pymysql.connect(host="localhost",
                       user="dbuser",
                       password="dbuserdbuser",
                       db="classicmodelsnew",
                       cursorclass=pymysql.cursors.DictCursor)


def get_order_details_by_customer(customerNumber=None):
    cur = conn.cursor()

    if customerNumber is not None:
        q = """
            select *
            from orders join orderdetails using(orderNumber)
                where customerNumber=%s order by orderNumber, orderLineNumber
        """
    else:
        q = """
            select *
            from orders join orderdetails using(orderNumber)
                order by orderNumber, orderLineNumber
        """

    res = cur.execute(q, (customerNumber))
    res = cur.fetchall()
    return res


def get_orders_by_customer(customerNumber):
    o_details = get_order_details_by_customer(customerNumber)
    orders = {}

    for o in o_details:
        c_o = orders.get(o["orderNumber"], None)

        if c_o is None:
            c_o = {
                "orderNumber": o["orderNumber"],
                "customerNumber": o["customerNumber"],
                "orderDate": o["orderDate"],
                "requiredDate": o["requiredDate"],
                "shippedDate": o["shippedDate"],
                "status": o["status"],
                "orderDetails": []
            }
        orders[o["orderNumber"]] = c_o

        new_d = {
            "orderLineNumber": o["orderLineNumber"],
            "productCode": o["productCode"],
            "quantityOrdered": o["quantityOrdered"],
            "priceEach": o["priceEach"]
        }
        orders[o["orderNumber"]]["orderDetails"].append(new_d)

    return orders


def load_all_orders():
    orders = get_orders_by_customer(None)
    return orders

# %%
res = get_order_details_by_customer(363)

# %%
res
# Out:
# [{'orderNumber': 10100,
#   'orderDate': datetime.date(2003, 1, 6),
#   'requiredDate': datetime.date(2003, 1, 13),
#   'shippedDate': datetime.date(2003, 1, 10),
#   'status': 'Shipped',
#   'comments': None,
#   'customerNumber': 363,
#   'productCode': 'S24_3969',
#   'quantityOrdered': 49,
#   'priceEach': Decimal('35.29'),
#   'orderLineNumber': 1},
#  {'orderNumber': 10100,
#   'orderDate': datetime.date(2003, 1, 6),
#   'requiredDate': datetime.date(2003, 1, 13),
#   'shippedDate': datetime.date(2003, 1, 10),
#   'status': 'Shipped',
#   'comments': None,
#   'customerNumber': 363,
#   'productCode': 'S18_2248',
#   'quantityOrdered': 50,
#   'priceEach': Decimal('55.09'),
#   'orderLineNumber': 2},
#  {'orderNumber': 10100,
#   'orderDate': datetime.date(2003, 1, 6),
#   'requiredDate': datetime.date(2003, 1, 13),
#   'shippedDate': datetime.date(2003, 1, 10),
#   'status': 'Shipped',
#   'comments': None,
#   'customerNumber': 363,
#   'productCode': 'S18_1749',
# ...

# %% [markdown]
# - Now make look like a "document order."

# %%
orders = get_orders_by_customer(363)
print("Orders = \n", json.dumps(orders, indent=2, default=str))
# Out:
# Orders =
#  {
#   "10100": {
#     "orderNumber": 10100,
#     "customerNumber": 363,
#     "orderDate": "2003-01-06",
#     "requiredDate": "2003-01-13",
#     "shippedDate": "2003-01-10",
#     "status": "Shipped",
#     "orderDetails": [
#       {
#         "orderLineNumber": 1,
#         "productCode": "S24_3969",
#         "quantityOrdered": 49,
#         "priceEach": "35.29"
#       },
#       {
#         "orderLineNumber": 2,
#         "productCode": "S18_2248",
#         "quantityOrdered": 50,
#         "priceEach": "55.09"
#       },
#       {
#         "orderLineNumber": 3,
#         "productCode": "S18_1749",
#         "quantityOrdered": 30,
#         "priceEach": "136.00"
#       },
#       {
#         "orderLineNumber": 4,
#         "productCode": "S18_4409",
#         "quantityOrdered": 22,
#         "priceEach": "75.46"
#       }
#     ]
#   },
#   "10192": {
#     "orderNumber": 10192,
#     "customerNumber": 363,
#     "orderDate": "2003-11-20",
# ...

# %% [markdown]
# # Let's Look "Migrate" to a Document Model

# %%
#
# Load all of the orders and convert to documents.
#
orders = load_all_orders()

# %%
orders
# Out:
# {10100: {'orderNumber': 10100,
#   'customerNumber': 363,
#   'orderDate': datetime.date(2003, 1, 6),
#   'requiredDate': datetime.date(2003, 1, 13),
#   'shippedDate': datetime.date(2003, 1, 10),
#   'status': 'Shipped',
#   'orderDetails': [{'orderLineNumber': 1,
#     'productCode': 'S24_3969',
#     'quantityOrdered': 49,
#     'priceEach': Decimal('35.29')},
#    {'orderLineNumber': 2,
#     'productCode': 'S18_2248',
#     'quantityOrdered': 50,
#     'priceEach': Decimal('55.09')},
#    {'orderLineNumber': 3,
#     'productCode': 'S18_1749',
#     'quantityOrdered': 30,
#     'priceEach': Decimal('136.00')},
#    {'orderLineNumber': 4,
#     'productCode': 'S18_4409',
#     'quantityOrdered': 22,
#     'priceEach': Decimal('75.46')}]},
#  10101: {'orderNumber': 10101,
#   'customerNumber': 128,
#   'orderDate': datetime.date(2003, 1, 9),
#   'requiredDate': datetime.date(2003, 1, 18),
#   'shippedDate': datetime.date(2003, 1, 11),
#   'status': 'Shipped',
# ...

# %%
#
# 
#
from datetime import datetime
from datetime import datetime, date
import decimal

# %%
#
# MongdoDB will create a database or collection if it does not exist.
#

print("The connection = ", mongo_conn)
print("The database = ", mongo_conn["classic_models"])
print("The collection = ", mongo_conn["classic_models"]["orders"])
# Out:
# The connection =  MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# The database =  Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'classic_models')
# The collection =  Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'classic_models'), 'orders')

# %%
#
# I DID NOT ENJOY THIS.
#
def map_types(d):
    for k, v in d.items():
        tt = type(v)
        if isinstance(v, date):
            v = datetime(
                year=v.year,
                month=v.month,
                day=v.day,
            )
        if isinstance(v, decimal.Decimal):
            v = float(v)

        if isinstance(v, dict):
            v = map_types(v)

        if isinstance(v, list):
            new_v = []
            for e in v:
                new_v.append(map_types(e))

        d[k] = v


    return d


def save_document_array(db_name, collection_name, doc_array):
    
    # Mongo will create the databases and collections on demand when inserting data.
    coll = mongo_conn[db_name][collection_name]
    
    for d in doc_array:
        
        #
        # Note, there is also an insertMany operations.
        #
        md = map_types(d)
        coll.insert_one(md)
        print("Inserted order = ", d["orderNumber"])

# %%
save_document_array("classic_models", "orders", orders.values())
# Out:
# Inserted order =  10100
# Inserted order =  10101
# Inserted order =  10102
# Inserted order =  10103
# Inserted order =  10104
# Inserted order =  10105
# Inserted order =  10106
# Inserted order =  10107
# Inserted order =  10108
# Inserted order =  10109
# Inserted order =  10110
# Inserted order =  10111
# Inserted order =  10112
# Inserted order =  10113
# Inserted order =  10114
# Inserted order =  10115
# Inserted order =  10116
# Inserted order =  10117
# Inserted order =  10118
# Inserted order =  10119
# Inserted order =  10120
# Inserted order =  10121
# Inserted order =  10122
# Inserted order =  10123
# Inserted order =  10124
# Inserted order =  10125
# Inserted order =  10126
# Inserted order =  10127
# Inserted order =  10128
# Inserted order =  10129
# Inserted order =  10130
# Inserted order =  10131
# Inserted order =  10132
# Inserted order =  10133
# Inserted order =  10134
# Inserted order =  10135
# Inserted order =  10136
# Inserted order =  10137
# ...

# %% [markdown]
# - Now, let's redo the find order by customerNumber.

# %%
def find_order_by_customer_number_mongo(customerNumber):
    
    # Mongo will create the databases and collections on demand when inserting data.
    coll = mongo_conn["classic_models"]["orders"]
    c_orders = coll.find({"customerNumber": customerNumber})
    
    res = []
    for o in c_orders:
        res.append(o)
        
    return res

# %%
c_orders = find_order_by_customer_number_mongo(363)
print("The orders for customer = 363 are: \n", json.dumps(c_orders, indent=2, default=str))
# Out:
# The orders for customer = 363 are:
#  [
#   {
#     "_id": "605cbb8f3f85e6026b83bf3f",
#     "orderNumber": 10100,
#     "customerNumber": 363,
#     "orderDate": "2003-01-06 00:00:00",
#     "requiredDate": "2003-01-13 00:00:00",
#     "shippedDate": "2003-01-10 00:00:00",
#     "status": "Shipped",
#     "orderDetails": [
#       {
#         "orderLineNumber": 1,
#         "productCode": "S24_3969",
#         "quantityOrdered": 49,
#         "priceEach": 35.29
#       },
#       {
#         "orderLineNumber": 2,
#         "productCode": "S18_2248",
#         "quantityOrdered": 50,
#         "priceEach": 55.09
#       },
#       {
#         "orderLineNumber": 3,
#         "productCode": "S18_1749",
#         "quantityOrdered": 30,
#         "priceEach": 136.0
#       },
#       {
#         "orderLineNumber": 4,
#         "productCode": "S18_4409",
#         "quantityOrdered": 22,
#         "priceEach": 75.46
#       }
#     ]
#   },
#   {
#     "_id": "605cbbce3f85e6026b83bf9b",
# ...

# %% [markdown]
# # Do an Update
#
# - Similar in concept to SQL: Takes a selection criteria (WHERE ...) and an update expression.

# %%
def get_order_by_number(o_number):
    coll = mongo_conn["classic_models"]["orders"]
    result = coll.find_one(
        {"orderNumber": o_number}
    )
    return result

# %%
o = get_order_by_number(10424)
print("Order = \n", json.dumps(o, indent=2, default=str))
# Out:
# Order =
#  {
#   "_id": "605cbbcf3f85e6026b83c083",
#   "orderNumber": 10424,
#   "customerNumber": 141,
#   "orderDate": "2005-05-31 00:00:00",
#   "requiredDate": "2005-06-08 00:00:00",
#   "shippedDate": null,
#   "status": "In Process",
#   "orderDetails": [
#     {
#       "orderLineNumber": 1,
#       "productCode": "S700_2824",
#       "quantityOrdered": 46,
#       "priceEach": 85.98
#     },
#     {
#       "orderLineNumber": 2,
#       "productCode": "S32_3522",
#       "quantityOrdered": 44,
#       "priceEach": 54.94
#     },
#     {
#       "orderLineNumber": 3,
#       "productCode": "S12_1666",
#       "quantityOrdered": 49,
#       "priceEach": 121.64
#     },
#     {
#       "orderLineNumber": 4,
#       "productCode": "S18_4668",
#       "quantityOrdered": 26,
#       "priceEach": 40.25
#     },
#     {
#       "orderLineNumber": 5,
#       "productCode": "S18_1097",
#       "quantityOrdered": 54,
#       "priceEach": 108.5
#     },
#     {
# ...

# %%
def update_order_shipped(o_number):
    
    coll = mongo_conn["classic_models"]["orders"]
    d = datetime.now()
    print(type(d))
    print(d)
    result = coll.update_one(
        {"orderNumber": o_number},
        {"$set": {"shippedDate": d}, "$set": {"status": "shipped"}}
    )
    return result

# %%
update_order_shipped(10424)
# Out:
# <class 'datetime.datetime'>
# 2021-03-25 13:14:56.580644

# %%
o = get_order_by_number(10424)
print("Order = \n", json.dumps(o, indent=2, default=str))
# Out:
# Order =
#  {
#   "_id": "605cbbcf3f85e6026b83c083",
#   "orderNumber": 10424,
#   "customerNumber": 141,
#   "orderDate": "2005-05-31 00:00:00",
#   "requiredDate": "2005-06-08 00:00:00",
#   "shippedDate": null,
#   "status": "shipped",
#   "orderDetails": [
#     {
#       "orderLineNumber": 1,
#       "productCode": "S700_2824",
#       "quantityOrdered": 46,
#       "priceEach": 85.98
#     },
#     {
#       "orderLineNumber": 2,
#       "productCode": "S32_3522",
#       "quantityOrdered": 44,
#       "priceEach": 54.94
#     },
#     {
#       "orderLineNumber": 3,
#       "productCode": "S12_1666",
#       "quantityOrdered": 49,
#       "priceEach": 121.64
#     },
#     {
#       "orderLineNumber": 4,
#       "productCode": "S18_4668",
#       "quantityOrdered": 26,
#       "priceEach": 40.25
#     },
#     {
#       "orderLineNumber": 5,
#       "productCode": "S18_1097",
#       "quantityOrdered": 54,
#       "priceEach": 108.5
#     },
#     {
# ...

# %% [markdown]
# <br>
#
# __Note: I spent an hour trying to get the darn shippedDate to map to a correct type from Python to MongoDB. Finally, I just swore and gave up.__
#
# <br>

# %% [markdown]
# # Aggregate/Pipeline

# %%
seasons = mongo_conn.GOT.seasons
seasons
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'GOT'), 'seasons')

# %% [markdown]
# - Suppose I want to know about scenes in "The Dothraki Sea?"
#
#
# - No problem. The filter is easy!

# %%
res = seasons.find({"episodes.scenes.location": "The Dothraki Sea"})

# %%
print("Show the result ...\n")
for r in res:
    print(json.dumps(r, indent=2, default=str))
# Out:
# Show the result ...
#
# {
#   "_id": "60577e50c68b67110968b6d1",
#   "season": "1",
#   "first_aired": "17-Apr-11",
#   "last_aired": "19-Jun-11",
#   "novels_notes": "A Game of Thrones",
#   "url": "https://gameofthrones.fandom.com/wiki/Season_1",
#   "episodes": [
#     {
#       "episodeNum": 1,
#       "episodeTitle": "Winter Is Coming",
#       "episodeLink": "/title/tt1480055/",
#       "episodeAirDate": "2011-04-17",
#       "episodeDescription": "Jon Arryn, the Hand of the King, is dead. King Robert Baratheon plans to ask his oldest friend, Eddard Stark, to take Jon's place. Across the sea, Viserys Targaryen plans to wed his sister to a nomadic warlord in exchange for an army.",
#       "openingSequenceLocations": [
#         "King's Landing",
#         "Winterfell",
#         "The Wall",
#         "Pentos"
#       ],
#       "scenes": [
#         {
#           "sceneStart": "0:00:40",
#           "sceneEnd": "0:01:45",
#           "location": "The Wall",
# ...

# %% [markdown]
# - Huh? There are clearly some information about scenes that did not happen in "The Dothraki Sea."
#
#
# - What happened? Well, how many things did I get back?

# %%
res = seasons.find({"episodes.scenes.location": "The Dothraki Sea"})
for r in res:
    print("Season number = ", r["season"])
# Out:
# Season number =  1
# Season number =  5
# Season number =  6

# %% [markdown]
# - Here is what happened:
#     - Seasons 1, 5 and 6 had at least 1 scene that occurred in "The Dothraki Sea".
#     - The match returns the all of the three documents. That is what matches do.
#     - I need some kind of project.
#
#
# - Think about transforming documents from one format to another. That is a lot more tricky than just "projecting" by selecting some columns.
#
#
# - MongoDB supports [Aggregation Pipelines](https://docs.mongodb.com/manual/reference/operator/aggregation-pipeline/) with a set of operators.
#
#
#
# - These can get pretty freaky ...
#
#
# - Let's change and try to just get some information about the scenes and not the entire documents.

# %%
 res = seasons.aggregate(
    [
        {"$unwind": { "path":"$episodes"}},
        {"$unwind": { "path": "$episodes.scenes", "includeArrayIndex": "sceneNum"}},
        {"$match": { "episodes.scenes.location": "The Dothraki Sea" }},
        { "$project":
             {
                 "season": 1, 
                 "episodeNum": "$episodes.episodeNum",
                 "_id": 0,
                 "sceneNum": 1,
                 "sceneStart": "$episodes.scenes.sceneStart",
                 "sceneEnd": "$episodes.scenes.sceneEnd",
                 "location": "$episodes.scenes.location",
                 "characters": "$episodes.scenes.characters"
             }
        }
    ]
 )
for r in res:
    print(json.dumps(r, indent=2, default=str))
# Out:
# {
#   "season": "1",
#   "sceneNum": 0,
#   "episodeNum": 2,
#   "sceneStart": "0:02:22",
#   "sceneEnd": "0:05:28",
#   "location": "The Dothraki Sea",
#   "characters": [
#     {
#       "name": "Jorah Mormont"
#     },
#     {
#       "name": "Daenerys Targaryen",
#       "title": "Khaleesi"
#     },
#     {
#       "name": "Khal Drogo",
#       "title": "Khal"
#     },
#     {
#       "name": "Viserys Targaryen"
#     },
#     {
#       "name": "Doreah"
#     },
#     {
#       "name": "Irri"
#     },
#     {
#       "name": "Jhiqui"
#     }
#   ]
# }
# {
#   "season": "1",
#   "sceneNum": 10,
#   "episodeNum": 2,
#   "sceneStart": "0:25:10",
#   "sceneEnd": "0:25:56",
#   "location": "The Dothraki Sea",
#   "characters": [
#     {
#       "name": "Khal Drogo",
#       "title": "Khal",
#       "sex": {
#         "with": [
#           "Daenerys Targaryen"
#         ],
#         "when": "present",
#         "type": "rape"
#       }
#     },
#     {
# ...

# %% [markdown]
# - Now, you might be tempted to state, "Yeah. Just fetching the documents and writing code in a normal language is easier."
#
#
# - It might be easier but, ...
#     - The matching information could be huge.
#     - You have to move a huge amount of data to the code to perform the refinement.
#     - The pipeline __runs on the database engine, in parallel, where the data is__ and only returns the result.
#
#
# - MongdoDB supports creating views.
